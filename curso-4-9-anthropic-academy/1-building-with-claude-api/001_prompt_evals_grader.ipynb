# %%
from urllib import response

# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 3.0

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere are several solutions to extract the bucket name from an S3 URI:\n\n## Solution 1: Using String Methods (Simple)\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove 's3://' prefix and split by '/'\n    return s3_uri.replace('s3://', '').split('/')[0]\n\n# Test\nprint(get_bucket_name('s3://my-bucket-name/path/to/object'))\n# Output: my-bucket-name\n```\n\n## Solution 2: Using Regular Expressions (Robust)\n```python\nimport re\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using regex\"\"\"\n    match = re.match(r's3://([a-z0-9\\-\\.]+)', s3_uri)\n    return match.group(1) if match else None\n\n# Test\nprint(get_bucket_name('s3://my-bucket-name/path/to/object'))\n# Output: my-bucket-name\n```\n\n## Solution 3: Using urllib (Production-Ready)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using urllib\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test\nprint(get_bucket_name('s3://my-bucket-name/path/to/object'))\n# Output: my-bucket-name\n```\n\n## Solution 4: Using Boto3 (AWS SDK)\n```python\nimport boto3\nfrom botocore.utils import parse_s3_url\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using boto3\"\"\"\n    parsed = parse_s3_url(s3_uri)\n    return parsed['bucket']\n\n# Test\nprint(get_bucket_name('s3://my-bucket-name/path/to/object'))\n# Output: my-bucket-name\n```\n\n## Comparison\n\n| Method | Pros | Cons |\n|--------|------|------|\n| **String Methods** | Simple, no dependencies | Minimal error handling |\n| **Regex** | Pattern validation | Need to maintain regex |\n| **urllib** | Standard library, clean | May need normalization |\n| **Boto3** | AWS-specific, validates format | Requires AWS SDK |\n\n## Recommendation\n\n- **Simple cases**: Use Solution 1\n- **Production code**: Use Solution 3 (urllib) or Solution 4 (boto3)\n- **Need validation**: Use Solution 2 (regex)",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., 's3://my-bucket-name/path/to/object') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 3.5,
#     "reasoning": "The solution demonstrates good breadth by offering multiple approaches with a helpful comparison. However, it oversimplifies the problem by not addressing critical edge cases, error handling, or full S3 bucket naming validation. While Solutions 3 and 4 are solid for production use, the lack of defensive coding examples and edge case discussion undermines the practical value for real-world AWS applications."
#   },
#   {
#     "output": "# AWS IAM Role CloudFormation Template\n\nHere's a complete JSON CloudFormation template snippet that defines an IAM role with a trust policy for EC2:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for IAM role with EC2 trust policy\",\n  \"Resources\": {\n    \"EC2TrustRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"EC2TrustRole\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"ec2.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"Description\": \"IAM role allowing EC2 instances to assume the role\"\n      }\n    }\n  },\n  \"Outputs\": {\n    \"RoleArn\": {\n      \"Description\": \"ARN of the created IAM role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2TrustRole\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"RoleName\": {\n      \"Description\": \"Name of the created IAM role\",\n      \"Value\": {\n        \"Ref\": \"EC2TrustRole\"\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n| Component | Purpose |\n|-----------|---------|\n| **AssumeRolePolicyDocument** | Trust policy defining who can assume the role |\n| **Principal.Service** | Specifies `ec2.amazonaws.com` as the trusted service |\n| **Action** | `sts:AssumeRole` allows EC2 to assume the role |\n| **Effect** | Set to \"Allow\" to grant permission |\n\n## Usage Notes:\n\n- This role alone grants no permissions. You'll need to attach policies to grant actual permissions\n- To use with EC2 instances, create an instance profile and attach this role to it\n- The trust policy is the only required component for role creation\n\nWould you like me to extend this example with additional policies or an instance profile?",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS IAM role with a basic trust policy allowing EC2 to assume the role",
#       "format": "json"
#     },
#     "score": 3.5,
#     "reasoning": "The solution accurately addresses the core requirement with syntactically correct CloudFormation JSON and a properly formatted trust policy for EC2. The explanation is clear and accessible. However, it contains a significant anti-pattern (hardcoded RoleName) and misses some practical guidance that would be expected in a production-ready example. The weaknesses are moderate rather than critical since the template would function correctly despite these issues."
#   },
#   {
#     "output": "# AWS Error Code to Human-Readable Message Mapper\n\n```python\ndef get_aws_error_message(error_code: str) -> str:\n    \"\"\"\n    Convert AWS error codes to human-readable error messages.\n    \n    Args:\n        error_code (str): AWS error code (e.g., 'AccessDenied', 'InvalidParameterValue')\n    \n    Returns:\n        str: Human-readable error message\n    \n    Examples:\n        >>> get_aws_error_message('AccessDenied')\n        'User does not have permission to access this resource'\n        \n        >>> get_aws_error_message('InvalidParameterValue')\n        'One or more parameter values are invalid'\n    \"\"\"\n    \n    # Comprehensive mapping of AWS error codes to human-readable messages\n    error_messages = {\n        # IAM & Access Control Errors\n        'AccessDenied': 'User does not have permission to access this resource',\n        'UnauthorizedOperation': 'You are not authorized to perform this operation',\n        'InvalidUserID.Malformed': 'The user ID is invalid or malformed',\n        'AuthFailure': 'AWS was not able to validate the provided access credentials',\n        \n        # Resource Errors\n        'InvalidInstanceID.NotFound': 'The specified instance does not exist',\n        'InvalidKeyPair.NotFound': 'The specified key pair does not exist',\n        'InvalidVolumeID.NotFound': 'The specified volume does not exist',\n        'InvalidSecurityGroupID.NotFound': 'The specified security group does not exist',\n        'ResourceNotFound': 'The requested resource was not found',\n        'InvalidResourceID.Malformed': 'The resource ID is invalid or malformed',\n        \n        # Parameter Errors\n        'InvalidParameterValue': 'One or more parameter values are invalid',\n        'InvalidParameterCombination': 'The parameters provided are invalid or incomplete',\n        'MissingParameter': 'Required parameter is missing',\n        'InvalidQueryParameter': 'The query parameter provided is invalid',\n        'InvalidRequest': 'The request is invalid',\n        \n        # Limit & Quota Errors\n        'InstanceLimitExceeded': 'Maximum instance count has been reached',\n        'QuotaExceeded': 'Resource quota has been exceeded',\n        'LimitExceeded': 'The request would exceed the resource limit',\n        'RequestLimitExceeded': 'Request rate limit has been exceeded',\n        'ThrottlingException': 'Request has been throttled, please try again later',\n        \n        # State Errors\n        'InvalidInstanceState.Incompatible': 'The instance is in an invalid state for this operation',\n        'InvalidState': 'The resource is in an invalid state',\n        'IncorrectInstanceState': 'The instance is in an incorrect state',\n        \n        # Network & Connectivity Errors\n        'InvalidAddress.Malformed': 'The IP address format is invalid',\n        'InvalidCIDRBlock.Malformed': 'The CIDR block format is invalid',\n        'InvalidNetworkInterface.NotFound': 'The specified network interface does not exist',\n        'NetworkInterfaceInUse': 'The network interface is currently in use',\n        'InvalidNetworkAclID.NotFound': 'The specified network ACL does not exist',\n        \n        # Snapshot & Image Errors\n        'InvalidSnapshot.NotFound': 'The specified snapshot does not exist',\n        'InvalidAMIID.NotFound': 'The specified AMI does not exist',\n        'InvalidAMIID.Malformed': 'The AMI ID is invalid or malformed',\n        'SnapshotInUse': 'The specified snapshot is currently in use',\n        \n        # DNS & Route53 Errors\n        'InvalidHostedZoneID': 'The hosted zone ID is invalid',\n        'InvalidChangeBatch': 'The change batch is invalid',\n        'ResourceRecordAlreadyExists': 'A resource record with that name already exists',\n        'InvalidInput': 'The input provided is invalid',\n        \n        # S3-related Errors\n        'NoSuchBucket':",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS error code string and returns a human-readable error message mapping (e.g., 'AccessDenied' -> 'User does not have permission to access this resource')",
#       "format": "python"
#     },
#     "score": 2.0,
#     "reasoning": "The solution demonstrates strong understanding of AWS error codes and excellent documentation practices. The mapping is comprehensive and well-organized. However, the code is incomplete (abruptly cut off) and lacks defensive programming practices like handling unmapped error codes. The function would fail at runtime with unknown error codes. These are critical issues that prevent the solution from being production-ready despite the solid foundation."
#   }
# ]
