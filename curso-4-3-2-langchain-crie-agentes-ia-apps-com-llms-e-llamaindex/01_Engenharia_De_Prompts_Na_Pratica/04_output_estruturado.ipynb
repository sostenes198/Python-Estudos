# %%
from dotenv import load_dotenv
from groq import Groq
import os

load_dotenv()

model = os.environ.get("LLM_MODEL")

client = Groq(
    api_key=os.environ.get("API_KEY_GROK")
)

# %% [markdown]
# ### Saída em Formato de Tabela

# %%
system_prompt = """
Você é um historiador especializado em civilizações antigas.
Sempre responda no formato de tabela:

| Civilização | Período | Contribuição Marcante | Região |
|-------------|---------|-----------------------|--------|
"""

user_prompt = "Crie uma tabela comparando 4 civilizações antigas (Egito, Mesopotâmia, Grécia, Roma)."

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    
    temperature=0.5
)

print(response.choices[0].message.content)
# Out:
# | Civilização | Período | Contribuição Marcante | Região |
# |-------------|---------|-----------------------|--------|
# | Egito Antigo | c. 3100 – 30 a.C. | Escrita hieroglífica, arquitetura monumental (pirâmides, templos) e sistema de governo centralizado sob os faraós | Vale do Nilo, Norte da África |
# | Mesopotâmia | c. 3500 – 539 a.C. | Invenção da escrita cuneiforme, códigos legais (Código de Hamurabi) e desenvolvimento da irrigação e da cidade‑estado | Entre os rios Tigre e Eufrates (atual Iraque) |
# | Grécia Antiga | c. 800 – 146 a.C. | Democracia ateniense, filosofia (Sócrates, Platão, Aristóteles), teatro, ciência e artes clássicas | Península Balcânica, ilhas do Egeu e costa da Ásia Menor |
# | Roma Antiga | c. 753 a.C. – 476 d.C. | Direito romano, engenharia (aquedutos, estradas, concreto), administração de um império vasto e latim como língua de referência | Península Itálica e, posteriormente, todo o Mediterrâneo ocidental |

# %% [markdown]
# ### Saída em uma Lista Simples

# %%
system_prompt_simples = "Você é um crítico de cinema que apresenta informações em listas claras."
user_prompt_simples = "Liste 5 filmes premiados no Oscar que marcaram a história do cinema."

response_simples = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt_simples},
        {"role": "user", "content": user_prompt_simples}
    ],
    temperature=0.6
)
print(response_simples.choices[0].message.content)
print()
# Out:
# **5 filmes premiados no Oscar que marcaram a história do cinema**
#
# | Filme | Ano de lançamento | Oscar(s) principal(is) | Por que ficou histórico |
# |-------|-------------------|------------------------|--------------------------|
# | **E o Vento Levou** (*Gone with the Wind*) | 1939 | Melhor Filme, Melhor Direção (Victor Fleming) e 7 prêmios no total | Primeiro grande épico de Hollywood a alcançar recorde de bilheteria; consolidou o formato de produção em larga escala e influenciou gerações de cineastas. |
# | **O Poderoso Chefão** (*The Godfather*) | 1972 | Melhor Filme, Melhor Ator (Marlon Brando) e 3 prêmios no total | Redefiniu o gênero de crime, elevando-o a arte; sua narrativa complexa e estética sombria inspiraram o cinema contemporâneo e a televisão. |
# | **A Lista de Schindler** (*Schindler’s List*) | 1993 | Melhor Filme, Melhor Diretor (Steven Spielberg) e 7 prêmios no total | Uso marcante do preto‑e‑branco para retratar o Holocausto; reforçou o papel do cinema como testemunho histórico e educacional. |
# | **Titanic** | 1997 | Melhor Filme, Melhor Direção (James Cameron) e 11 prêmios (recorde na época) | Demonstrou o potencial dos efeitos digitais e do CGI em escala épica; tornou‑se o filme de maior bilheteria da história até ser superado por *Avatar* (2009). |
# | **Parasita** (*Parasite*) | 2019 | Melhor Filme (primeiro filme não‑inglês a vencer), Melhor Direção (Bong Joon‑ho) e 4 prêmios no total | Quebrou barreiras linguísticas no Oscar; trouxe à tona discussões sobre desigualdade social e mostrou a força do cinema sul‑coreano no cenário global. |
#
# *Esses títulos não apenas colecionaram estatuetas, mas também influenciaram técnicas, narrativas e a própria percepção do público sobre o que o cinema pode ser.*

# %% [markdown]
# ### Lista Numerada

# %%
system_prompt_numerada = """
Você cria listas numeradas no formato:
1. [Título]: [Descrição curta]
"""
user_prompt_numerada = "Liste 4 estratégias de treinamento usadas por atletas olímpicos."

response_numerada = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt_numerada},
        {"role": "user", "content": user_prompt_numerada}
    ],
    max_completion_tokens=200,
    temperature=0.6
)
print(response_numerada.choices[0].message.content)
print()
# Out:
# 1. Periodização de Carga: Estrutura o treinamento em ciclos de volume e intensidade para otimizar picos de performance.
# 2. Treinamento de Alta Intensidade (HIIT): Sessões curtas e intensas que aumentam a capacidade aeróbica e anaeróbica.
# 3. Simulação de Competição: Replicação das condições de prova (tempo, ambiente, pressão) para adaptar o atleta ao cenário real.
# 4. Recuperação Ativa: Atividades leves

# %% [markdown]
# ### Lista Hierárquica

# %%
system_prompt_hierarquica = """
Você organiza informações em listas hierárquicas no formato:
• Categoria Principal
  - Subcategoria 1
  - Subcategoria 2
"""
user_prompt_hierarquica = "Organize áreas da ciência em categorias: Física, Biologia, Química."

response_hierarquica = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt_hierarquica},
        {"role": "user", "content": user_prompt_hierarquica}
    ],
    temperature=0.6
)
print(response_hierarquica.choices[0].message.content)
# Out:
# • Física
#   - Mecânica Clássica
#   - Termodinâmica
#   - Eletromagnetismo
#   - Física Quântica
#   - Relatividade
#   - Física de Partículas
#   - Física Nuclear
#   - Física de Condensados
#
# • Biologia
#   - Biologia Molecular
#   - Genética
#   - Ecologia
#   - Evolução
#   - Zoologia
#   - Botânica
#   - Microbiologia
#   - Fisiologia
#
# • Química
#   - Química Orgânica
#   - Química Inorgânica
#   - Química Analítica
#   - Química Física
#   - Bioquímica
#   - Química Ambiental
#   - Química Teórica
#   - Química de Materiais

# %% [markdown]
# ### Parágrafos Estruturados

# %%
system_prompt = """
Você escreve textos estruturados no formato:

INTRODUÇÃO: [1-2 frases de contexto]
DESENVOLVIMENTO: [Explicação detalhada]
CONCLUSÃO: [Síntese final]
"""

user_prompt = "Explique a importância da moda como expressão cultural."

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.7
)

print(response.choices[0].message.content)
# Out:
# **INTRODUÇÃO:** A moda transcende o simples ato de vestir, funcionando como um reflexo visível das identidades, valores e histórias de uma sociedade. Ao observar roupas e estilos, podemos ler narrativas culturais que revelam quem somos e como nos posicionamos no mundo.
#
# **DESENVOLVIMENTO:**
# - **Identidade e pertencimento:** As escolhas de vestuário permitem que indivíduos expressem sua origem étnica, classe social, gênero e orientação sexual. Trajes tradicionais, como o kimono japonês ou o traje afro‑brasileiro, reforçam laços com a comunidade e preservam memórias coletivas.
# - **Dinâmica histórica:** Cada época deixa marcas na moda – os vestidos volumosos do barroco, os cortes austeros da Revolução Francesa ou o streetwear dos anos 2000. Essas mudanças registram transformações políticas, econômicas e tecnológicas, funcionando como um arquivo visual da evolução humana.
# - **Comunicação simbólica:** Cores, padrões e acessórios carregam significados simbólicos. Por exemplo, o vermelho pode simbolizar poder ou celebração, enquanto estampas florais podem evocar feminilidade ou conexão com a natureza. Designers utilizam esses símbolos para comentar questões sociais, como igualdade de gênero ou sustentabilidade.
# - **Inovação e intercâmbio cultural:** A globalização intensificou o fluxo de ideias estilísticas entre continentes, gerando fusões criativas que enriquecem o repertório cultural. O uso de tecidos tradicionais em coleções contemporâneas promove o reconhecimento e a valorização de técnicas artesanais antes marginalizadas.
# - **Economia criativa:** A moda gera empregos, fomenta indústrias (têxtil, marketing, mídia) e impulsiona o turismo cultural. Festivais de moda, como a Paris Fashion Week, tornam-se vitrines de poder simbólico, atraindo investimento e projetando a cultura de um país no cenário internacional.
#
# **CONCLUSÃO:** Assim, a moda funciona como um espelho e um agente de mudança cultural, revelando identidades, narrando histórias e influenciando a sociedade. Reconhecê‑la como expressão cultural é essencial para compreender a complexidade humana e valorizar a diversidade que enriquece o nosso mundo.

# %% [markdown]
# ### Formato Customizado

# %%
system_prompt_card = """
Você cria cards informativos sobre missões espaciais no formato:

🚀 MISSÃO: [Nome]
📅 ANO: [Ano]
🌌 OBJETIVO: [Resumo em 1 frase]
🔭 RESULTADO: [Principais descobertas]
"""
user_prompt_card = "Crie um card sobre a missão Voyager 1."

response_card = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt_card},
        {"role": "user", "content": user_prompt_card}
    ],
    temperature=0.6
)
print(response_card.choices[0].message.content)
print()
# Out:
# 🚀 **MISSÃO:** Voyager 1
# 📅 **ANO:** 1977
# 🌌 **OBJETIVO:** Explorar os planetas externos (Júpiter e Saturno) e, posteriormente, deixar o Sistema Solar para estudar o espaço interestelar.
# 🔭 **RESULTADO:** Primeira sonda a sobrevoar Júpiter (1979) e Saturno (1980), enviando imagens e dados detalhados de suas atmosferas, luas e anéis; em 2012 tornou‑se o primeiro objeto humano a entrar no espaço interestelar, fornecendo medições inéditas de partículas, campos magnéticos e radiação além da heliosfera.

# %% [markdown]
# ### Formato Checklist

# %%
system_prompt_checklist = """
Você cria checklists no formato:

✅ [Tarefa 1]
✅ [Tarefa 2]
✅ [Tarefa 3]
"""
user_prompt_checklist = "Monte um checklist para organizar um festival de música ao ar livre."

response_checklist = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt_checklist},
        {"role": "user", "content": user_prompt_checklist}
    ],
    max_completion_tokens=400,
    temperature=0.6
)
print(response_checklist.choices[0].message.content)
# Out:
# ✅ Definir objetivo, tema e data do festival
# ✅ Escolher e reservar o local ao ar livre (considerar capacidade, acesso, infraestrutura)
# ✅ Obter licenças e autorizações necessárias (alvará municipal, licença ambiental, direitos autorais)
# ✅ Contratar seguro de responsabilidade civil e cobertura de eventos
# ✅ Elaborar orçamento detalhado (custo de artistas, produção, segurança, marketing, imprevistos)
# ✅ Selecionar e fechar contrato com artistas/bandas e definir cachês e rider técnico
# ✅ Contratar produtores de som, iluminação e palco (incluindo montagem e desmontagem)
# ✅ Planejar layout do evento (palco, áreas de público, bastidores, áreas VIP, banheiros, alimentação, primeiros socorros)
# ✅ Definir plano de segurança (seguranças, controle de acesso, controle de multidões, plano de evacuação)
# ✅ Contratar equipe de segurança e vigilância (seguranças privados, polícia local)
# ✅ Contratar equipe de primeiros socorros e ambulância (medicina de emergência, paramédicos)
# ✅

# %% [markdown]
# ### Unindo tudo

# %%
system_prompt = """
Você cria relatórios executivos no formato:

📊 RESUMO
[Resumo em 2-3 frases]

📈 DESTAQUES
1. [Ponto-chave 1]
2. [Ponto-chave 2]
3. [Ponto-chave 3]

💡 RECOMENDAÇÕES
• Curto prazo: [Ação imediata]
• Médio prazo: [Ação estratégica]
• Longo prazo: [Visão futura]
"""

user_prompt = """
Crie um relatório executivo sobre os impactos da exploração de Marte para a economia global.
"""

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    max_completion_tokens=700,
    temperature=0.6
)

print(response.choices[0].message.content)
# Out:
# 📊 **RESUMO**
# A exploração de Marte está acelerando a inovação tecnológica, gerando novos mercados e estimulando investimentos em setores estratégicos. Esses desenvolvimentos têm o potencial de impulsionar o crescimento econômico global, embora exijam políticas coordenadas para maximizar benefícios e mitigar riscos.
#
# 📈 **DESTAQUES**
# 1. **Multiplicação de cadeias de suprimentos de alta tecnologia** – a demanda por sistemas de propulsão, robótica avançada e materiais leves está ampliando indústrias aeroespaciais, de semicondutores e de manufatura aditiva.
# 2. **Novas oportunidades de investimento e financiamento** – fundos de capital de risco, parcerias público‑privadas e programas de crédito governamentais estão surgindo para apoiar startups e projetos de infraestrutura espacial.
# 3. **Impactos macroeconômicos e geopolíticos** – a corrida por recursos extraterrestres (água, minerais) está redefinindo a competitividade internacional e pode gerar novos acordos comerciais e regulatórios.
#
# 💡 **RECOMENDAÇÕES**
# - **Curto prazo:** Criar incentivos fiscais e subsídios direcionados a P&D de tecnologias críticas (propulsão elétrica, impressão 3D em ambientes extremos) para acelerar a transferência de know‑how para a indústria civil.
# - **Médio prazo:** Estabelecer um marco regulatório internacional que padronize a extração e o uso de recursos marcianos, facilitando joint ventures entre governos e setor privado e reduzindo barreiras comerciais.
# - **Longo prazo:** Investir em infraestrutura de suporte (portos espaciais, sistemas de comunicação interplanetária) e em programas de capacitação de força‑trabalho especializada, garantindo que a economia global esteja preparada para uma era de economia espacial sustentável.
