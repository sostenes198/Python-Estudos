# %%
from dotenv import load_dotenv
from groq import Groq
import os

load_dotenv()

model = os.environ.get("LLM_MODEL")

client = Groq(
    api_key=os.environ.get("API_KEY_GROK")
)

# %% [markdown]
# ### Análise Textual 1 - Cores e Ambientes

# %%
system_prompt = """
Você é um especialista em análise visual. Dada uma descrição de imagem, identifique:
1. Paleta de cores dominante
2. Clima ou atmosfera sugerida
3. Elementos de cenário
"""

user_prompt = """
Descrição:

"Uma praia ao entardecer, com o céu em tons de laranja e roxo,
ondas suaves batendo na areia clara e algumas gaivotas voando no horizonte."
"""

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.3
)

print("=== RESULTADO (Cores e Ambientes) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Cores e Ambientes) ===
# **1. Paleta de cores dominante**
# - **Laranja quente** (tons do pôr‑do‑sol no céu)
# - **Roxo profundo** (gradiente do céu ao entardecer)
# - **Bege/areia clara** (areia da praia)
# - **Azul suave** (ondas e reflexos na água)
# - **Branco/cinza claro** (gaivotas e espuma das ondas)
#
# **2. Clima ou atmosfera sugerida**
# - **Clima ameno e tranquilo**: brisa leve, temperatura agradável ao entardecer.
# - **Atmosfera romântica e serena**: luz dourada do sol poente, cores quentes que criam um sentimento de calma e contemplação.
# - **Sensação de liberdade**: o voo das gaivotas no horizonte reforça a ideia de espaço aberto e paz.
#
# **3. Elementos de cenário**
# - **Praia**: areia clara, extensão de areia que se funde com o mar.
# - **Mar/Ondas**: ondas suaves que chegam à margem, criando espuma delicada.
# - **Céu ao entardecer**: gradiente de laranja para roxo, possivelmente com algumas nuvens finas.
# - **Gaivotas**: aves em voo, posicionadas no horizonte, adicionando movimento ao cenário.
# - **Horizonte**: linha onde o mar encontra o céu, marcando a profundidade da paisagem.
#
# Esses componentes juntos criam uma imagem visual de um fim de tarde pacífico à beira‑mar, ideal para transmitir tranquilidade e beleza natural.

# %% [markdown]
# ### Análise Textual 2 - Objetos e Elementos

# %%
system_prompt = """
Você é um analista de imagens em texto. Identifique:
1. Objetos principais
2. Relações entre eles
3. Elementos secundários
"""

user_prompt = """
Descrição:

"Um escritório moderno com uma mesa de madeira, um laptop aberto,
uma xícara de café fumegante e uma estante cheia de livros ao fundo."
"""

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.4
)

print("=== RESULTADO (Objetos e Elementos) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Objetos e Elementos) ===
# **1. Objetos principais**
# - Mesa de madeira
# - Laptop aberto
# - Xícara de café fumegante
# - Estante cheia de livros (localizada ao fundo)
#
# **2. Relações entre eles**
# - **Laptop** está **sobre** a mesa de madeira, indicando que está sendo usado ou pronto para uso.
# - **Xícara de café** também está **sobre** a mesa, provavelmente ao lado ou próximo ao laptop, sugerindo uma situação de trabalho/estudo.
# - **Estante** está **posicionada atrás** da mesa, formando o plano de fundo da cena.
# - A **mesa**, o **laptop** e a **xícara** formam um conjunto funcional de trabalho, enquanto a **estante** fornece suporte visual e contextual (acesso a livros, ambiente de estudo).
#
# **3. Elementos secundários (implícitos ou de apoio)**
# - **Ambiente de escritório moderno** (design clean, iluminação possivelmente natural ou de teto).
# - **Cadeira** (presumida, já que há uma mesa de trabalho).
# - **Parede** ou divisória que sustenta a estante.
# - **Luz** (natural ou artificial) que ilumina a mesa e o laptop.
# - **Detalhes de decoração** (por exemplo, um quadro na parede, um tapete, plantas) que ajudam a compor o estilo “moderno”.
#
# Esses elementos secundários não foram explicitamente mencionados, mas são típicos de um cenário de escritório contemporâneo e ajudam a contextualizar a disposição dos objetos principais.

# %% [markdown]
# ### Análise Textual 3 - Análise Simbólica

# %%
system_prompt = """
Você é um especialista em semiótica visual. Interprete:
1. Significados simbólicos dos elementos
2. Possíveis metáforas
3. Impacto emocional no observador
"""

user_prompt = """
Descrição:

"Uma vela acesa em meio a uma sala escura,
iluminando apenas um diário aberto e uma fotografia antiga."
"""

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("=== RESULTADO (Análise Simbólica) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Análise Simbólica) ===
# ## 1. Significados simbólicos dos elementos
#
# | Elemento | Significado tradicional / cultural | Leitura semiótica no contexto da cena |
# |----------|-----------------------------------|--------------------------------------|
# | **Vela acesa** | • Luz interior, esperança, vida que persiste.<br>• Sacrifício (cera que se consome).<br>• Ritual, memória, espiritualidade (cultura judaica – *shabat*, católica – *vigília*). | A vela funciona como **signo indexical**: aponta para algo que está faltando (a luz geral da sala) e, ao mesmo tempo, **signo icônico** da fragilidade da existência – a chama pode se apagar a qualquer momento. Ela indica que alguém está tentando “preservar” ou “reviver” algo que está quase perdido. |
# | **Sala escura** | • Ignorância, desconhecido, luto, interioridade profunda.<br>• Espaço de introspecção, “caverna da mente”. | O fundo negro atua como **campo semântico de ausência**. Ele amplifica a presença da vela, criando um contraste que destaca o que é importante. Também funciona como **signo simbólico de “o inconsciente”**: tudo o que está fora da luz permanece oculto, sugerindo segredos ou memórias reprimidas. |
# | **Diário aberto** | • Testemunho pessoal, verdade íntima, narrativa em construção.<br>• Registro do tempo, vulnerabilidade (as palavras são expostas). | O diário é um **signo arbitrário** que representa a voz do sujeito. O fato de estar aberto indica **disponibilidade** ou **exposição**: o narrador está pronto a ser lido, a ser compreendido. Em termos de semiótica, ele funciona como um *texto* que “conversa” com a imagem da vela – a luz ilumina a escrita, sugerindo que a memória só ganha vida quando é trazida à luz. |
# | **Fotografia antiga** | • Passado congelado, nostalgia, memória visual.<br>• Testemunho de gerações, identidade familiar.<br>• O “tempo morto” que ainda fala. | A foto funciona como **ícone** (representa visualmente o que já foi) e como **símbolo de permanência** (a imagem persiste enquanto o papel pode se deteriorar). Sua presença ao lado do diário cria um **encadeamento intertextual**: a escrita descreve, a foto mostra. Ambas são “memórias” que precisam de luz para serem percebidas. |
#
# ## 2. Possíveis metáforas
#
# 1. **“A chama da memória”** – A vela simboliza a energia que mantém viva a lembrança; sem ela, o diário e a foto desaparecem no esquecimento.
# 2. **“Escrita na penumbra da história”** – O ambiente escuro representa o tempo que se esvai; a luz da vela indica que a história só se torna legível quando alguém a procura ativamente.
# 3. **“Ritual de reconciliação”** – Acender a vela em meio à escuridão pode ser visto como um ato de **ritual de luto** ou de **reconciliação com o passado**; o diário aberto sugere que o sujeito está confrontando sentimentos não resolvidos, enquanto a foto antiga traz à tona rostos ou momentos que precisam ser reconhecidos.
# 4. **“O presente como guardião do passado”** – A vela (presente) protege e revela o passado (diário e foto). Essa relação pode ser lida como uma **metáfora de responsabilidade intergeracional**: quem está vivo tem o dever de iluminar e preservar o que veio antes.
# 5. **“A fragilidade da identidade”** – Tanto a chama quanto a fotografia são efêmeras (a chama pode se apagar; a foto pode desbotar). Juntas, elas sugerem que a identidade pessoal é construída sobre elementos frágeis que precisam de cuidado constante.
#
# ## 3. Impacto emocional no observador
#
# | Aspecto visual | Efeito emocional provável | Por quê? |
# |----------------|--------------------------|----------|
# | **Contraste luz/trevas** | **Intimidade + tensão** – O observador sente-se “convidado” a entrar no espaço restrito, mas também percebe a vulnerabilidade da cena. | O contraste cria foco e ao mesmo tempo um senso de claustrofobia suave; a luz quente da vela gera conforto, enquanto a escuridão circundante gera ansiedade. |
# | **Vela tremeluzente** | **Esperança melancólica** – A chama vacila, lembrando a instabilidade da esperança. | O movimento sutil da chama evoca a ideia de que a esperança pode ser tanto reconfortante quanto incerta. |
# | **Diário aberto** | **Curiosidade + empatia** – O leitor sente vontade de ler o que está escrito, projetando-se na intimidade do autor. | O ato de abrir um diário é um convite à vulnerabilidade; o observador sente que está “espiando” segredos. |
# | **Fotografia antiga** | **Nostalgia, saudade, melancolia** – A imagem de um tempo passado evoca lembranças pessoais ou coletivas. | Fotografias são “portais” para o passado; ao serem iluminadas, parecem “reviver”, gerando um sentimento de perda e ao mesmo tempo de preservação. |
# | **Ambiente silencioso** (implicação) | **Reflexão profunda** – O silêncio da sala escura convida à contemplação interna. | A ausência de ruído visual ou auditivo permite que o observador projete seus próprios pensamentos e emoções sobre a cena. |
#
# ### Resumo emocional
#
# A composição produz um **clima de reverência silenciosa**: o observador sente simultaneamente a **calorosa proximidade** da chama (conforto, esperança) e a **fria vastidão** da escuridão (incerteza, luto). O diário e a foto funcionam como “testemunhas” que pedem ser lembradas, gerando **nostalgia** e um **sentimento de responsabilidade** – como se fosse necessário “acender” a própria vela interior para não deixar que essas memórias se percam. Essa tensão entre luz e sombra, entre o presente que ilumina e o passado que permanece na penumbra, cria uma experiência emocional rica, que pode levar o observador a refletir sobre suas próprias histórias não contadas e sobre o papel da memória na construção da identidade.

# %% [markdown]
# ### Análise Comparativa

# %%
descricao_a = "Um campo de trigo dourado sob um céu azul claro, com uma árvore solitária no horizonte."
descricao_b = "Uma metrópole movimentada à noite, cheia de arranha-céus iluminados e ruas lotadas."

comparison_prompt = f"""
Compare estas duas descrições de imagens:
1. Diferenças de cores e atmosfera
2. Elementos principais
3. Estilos possíveis
4. Emoções transmitidas

DESCRIÇÃO A: {descricao_a}

DESCRIÇÃO B: {descricao_b}
"""

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "user", "content": comparison_prompt}
    ],
    temperature=0.4
)

print("=== RESULTADO (Análise Comparativa) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Análise Comparativa) ===
# **Comparação entre a Descrição A (campo de trigo) e a Descrição B (metrópole noturna)**
#
# | Aspecto | Descrição A – Campo de trigo | Descrição B – Metrópole noturna |
# |---|---|---|
# | **1. Diferenças de cores e atmosfera** | **Cores:** predominância de tons quentes e naturais – dourado do trigo, verde‑amarelado da vegetação, azul claro do céu. <br>**Atmosfera:** calma, aberta, serena; sensação de amplitude e luz natural suave. | **Cores:** contrastes fortes entre luzes artificiais (neon, amarelo, branco) e sombras escuras do céu noturno; predominam tons escuros (preto, azul‑marinho) pontuados por brilhos coloridos. <br>**Atmosfera:** vibrante, agitada, densa; sensação de movimento constante e energia urbana. |
# | **2. Elementos principais** | • Campo de trigo dourado <br>• Céu azul claro <br>• Árvore solitária no horizonte (ponto focal) <br>• Linha do horizonte baixa, sugerindo vastidão. | • Arranha‑céus iluminados (silhuetas e fachadas de vidro) <br>• Ruas lotadas de veículos e pedestres <br>• Luzes de néon, anúncios e faróis <br>• Céu noturno com pouca ou nenhuma luz natural. |
# | **3. Estilos possíveis** | - **Paisagem pastoral / romântica** <br>- **Realismo naturalista** <br>- **Pintura impressionista** (ênfase na luz dourada) <br>- **Fotografia de golden hour** <br>- **Ilustração minimalista** (árvore solitária como símbolo). | - **Cyber‑punk / futurista** <br>- **Noir urbano** <br>- **Fotografia de longa exposição** (rastro de luzes) <br>- **Arte digital de cidade neon** <br>- **Realismo urbano contemporâneo**. |
# | **4. Emoções transmitidas** | - **Tranquilidade** e paz interior <br>- **Nostalgia** por cenários rurais <br>- **Simplicidade** e conexão com a natureza <br>- **Esperança** (céu aberto, luz do dia). | - **Excitação** e adrenalina <br>- **Ansiedade** ou sobrecarga sensorial (multidão, luzes) <br>- **Fascínio** pela modernidade e tecnologia <br>- **Solidão urbana** (pessoas anônimas em meio à multidão). |
#
# ### Resumo geral
# - **Cores e atmosfera**: A descrição A usa paleta quente e natural, gerando serenidade; a B usa contrastes escuros‑luminosos, criando dinamismo e tensão.
# - **Elementos**: A A foca em natureza e espaço aberto; a B concentra‑se em arquitetura, iluminação artificial e fluxo de gente.
# - **Estilos**: A A remete a estilos clássicos e contemplativos; a B abre caminho para abordagens futuristas, neon‑heavy e de alta energia.
# - **Emoções**: Enquanto A evoca calma, nostalgia e conexão com o campo, B desperta excitação, curiosidade urbana e, ao mesmo tempo, uma possível sensação de alienação.
#
# Essas diferenças mostram como duas simples descrições podem conduzir a mundos visuais e sensoriais completamente opostos.
