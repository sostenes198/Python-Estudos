# %%
from dotenv import load_dotenv
from groq import Groq
import os

load_dotenv()

model = os.environ.get("LLM_MODEL")

client = Groq(
    api_key=os.environ.get("API_KEY_GROK")
)

# %% [markdown]
# # Parâmetros Importantes
#
# * temeparture: Controla a aletoriedade, das respostas. Valores entre 0.0 e 1.0 são aceitos
# * max_completion_tokens: Define o número máximos de tokens que podem ser gerados pelo modelo. Esses parâmetros subistitui o max_tokens em desuso.
# * top_p: Controla a diversidade via "nuclueus sampling" -- em torno de 0.5 significa considerar apenas os tokens que somam 50% de probabilidade

# %% [markdown]
# # Usando Temperature

# %%
prompt = "Escreva uma frase poética sobre o anoitecer"

# Temperature 0.0 (Determinística)
print("Temperatura 0.0 (Determinística)")
response_low = client.chat.completions.create(
    model=model,
    temperature=0.0,
    messages=[
        {"role": "system", "content": "Você é um poeta minimalista que descreve a natureza de forma simples e direta."},
        {"role": "user", "content": prompt}
    ]
)

print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# Temperatura 0.0 (Determinística)
# Resposta: O céu se fecha em tons de silêncio, enquanto a noite abre seu véu.

# %%
# Temperature média (0.7) - Equilibrada
print("Temperature 0.7 (Equilibrada):")
response_medium = client.chat.completions.create(
    model=model,
    temperature=0.7,
    messages=[
        {"role": "system", "content": "Você é um poeta clássico que mistura metáforas e imagens da natureza."},
        {"role": "user", "content": prompt}
    ],

)
print(f"Resposta: {response_medium.choices[0].message.content}\n")
# Out:
# Temperature 0.7 (Equilibrada):
# Resposta: No crepúsculo, o céu se veste de ouro e violeta, como um lago sereno que reflete o último suspiro do sol antes que a noite, em véu de seda, abrace a terra adormecida.

# %%
# Temperature alta (1.5) - Mais criativa
print("Temperature 1.5 (Criativa):")
response_high = client.chat.completions.create(
    model=model,
    temperature=1.5,
    messages=[
        {"role": "system", "content": "Você é um poeta surrealista que usa imagens improváveis e linguagem ousada."},
        {"role": "user", "content": prompt}
    ],
)
print(f"Resposta: {response_high.choices[0].message.content}")
# Out:
# Temperature 1.5 (Criativa):
# Resposta: O crepúsculo desponta como um pinguim de neon que mergulha o céu em tinta de melancia, enquanto os relógios de vento suspensos cantam silêncio em forma de folhas de aço.

# %% [markdown]
# # Usando top_p

# %%
prompt = "Complete a frase: 'A inteligência artificial no futuro será...'"
print("=== Comparação Top_p ===\n")

# Top_p baixo (0.1) - Mais focado
print("Top_p 0.1 (Focado):")
response_focused = client.chat.completions.create(
    model=model,
    temperature=1.0,  # fixo para comparar só o efeito do top_p
    top_p=0.1,
    messages=[
        {"role": "system", "content": "Você é um futurista que faz previsões sérias e objetivas sobre tecnologia."},
        {"role": "user", "content": prompt}
    ]
)
print(f"Resposta: {response_focused.choices[0].message.content}\n")
# Out:
# === Comparação Top_p ===
#
# Top_p 0.1 (Focado):
# Resposta: **A inteligência artificial no futuro será** uma camada onipresente de infraestrutura cognitiva, tão essencial quanto a eletricidade ou a internet, capaz de compreender, aprender e agir em tempo real em contextos cada vez mais complexos.
#
# - **Integração profunda**: IA será incorporada a praticamente todos os dispositivos e sistemas — de cidades inteligentes a veículos autônomos, de plataformas de saúde a ambientes de trabalho — permitindo decisões automatizadas que otimizam recursos, reduzem desperdícios e melhoram a qualidade de vida.
#
# - **Autonomia contextual**: Algoritmos avançados de aprendizado de máquina e de raciocínio simbólico combinarão para oferecer autonomia contextual, ou seja, a capacidade de adaptar seu comportamento não apenas com base em dados históricos, mas também entendendo nuances do ambiente, intenções humanas e normas sociais em tempo real.
#
# - **Governança ética embutida**: Modelos de IA serão desenvolvidos com mecanismos de transparência, auditabilidade e controle de viés integrados desde a fase de design, obedecendo a padrões regulatórios globais que garantam responsabilidade, privacidade e alinhamento com valores humanos.
#
# - **Co‑criação homem‑máquina**: Em vez de substituir profissionais, a IA atuará como colaboradora avançada, ampliando a criatividade e a produtividade humana em áreas como ciência, arte, engenharia e educação, por meio de interfaces neurais e de linguagem natural cada vez mais intuitivas.
#
# - **Resiliência e segurança**: Infraestruturas de IA serão projetadas para operar de forma resiliente contra falhas, ataques cibernéticos e manipulações, utilizando técnicas de verificação formal, redundância distribuída e aprendizado contínuo de ameaças.
#
# Em resumo, a IA do futuro será uma **tecnologia de suporte cognitivo universal**, segura, ética e altamente adaptável, que ampliará as capacidades humanas e sustentará a complexidade crescente das sociedades modernas.

# %%
# Top_p médio (0.7) - Equilibrado
print("Top_p 0.7 (Equilibrado):")
response_balanced = client.chat.completions.create(
    model=model,
    temperature=1.0,
    top_p=0.7,
    messages=[
        {"role": "system",
         "content": "Você é um futurista que mistura objetividade com toques criativos em previsões."},
        {"role": "user", "content": prompt}
    ]

)
print(f"Resposta: {response_balanced.choices[0].message.content}\n")
# Out:
# === Comparação Top_p ===
#
# Top_p 0.7 (Focado):
# Resposta: **A inteligência artificial no futuro será** uma camada onipresente de suporte cognitivo que ampliará a capacidade humana de forma integrada, segura e transparente.
#
# - **Onipresença contextualizada:** Em vez de estar confinada a aplicativos isolados, a IA será incorporada a ambientes físicos e digitais — casas, cidades, fábricas e dispositivos vestíveis — adaptando seu comportamento ao contexto em tempo real e antecipando necessidades antes mesmo de serem explicitamente solicitadas.
#
# - **Colaboração homem‑máquina:** Em vez de substituir tarefas, a IA atuará como assistente cognitivo, filtrando informações, gerando insights e co‑criando soluções. Profissionais de todas as áreas contarão com “cobras de pensamento” que sugerem hipóteses, detectam anomalias e otimizam processos, permitindo que o foco humano se concentre em criatividade, empatia e julgamento ético.
#
# - **Governança baseada em valores:** Modelos avançados serão desenvolvidos dentro de frameworks de responsabilidade, auditabilidade e explicabilidade. Cada decisão crítica terá trilhas de auditoria que permitem rastrear a lógica subjacente, garantindo conformidade com normas regulatórias e princípios de justiça.
#
# - **Especialização modular:** Em vez de um único modelo monolítico, haverá ecossistemas de IA modulares, cada um especializado em domínio (saúde, energia, finanças, educação) e interoperáveis via padrões abertos. Essa arquitetura reduzirá o risco de viés sistêmico e facilitará a atualização incremental de capacidades.
#
# - **Autonomia controlada:** Sistemas autônomos (veículos, drones, robôs industriais) operarão com níveis graduais de autonomia, sempre sob supervisão humana de “último recurso”. Algoritmos de verificação em tempo real garantirão que comportamentos emergentes permaneçam dentro de limites seguros predefinidos.
#
# - **Impacto econômico e social equilibrado:** A IA impulsionará produtividade e criará novos mercados, mas também exigirá políticas de requalificação e redes de segurança social para mitigar a disrupção no emprego. A colaboração entre governos, academia e setor privado será crucial para distribuir os benefícios de forma equitativa.
#
# Em resumo, a inteligência artificial no futuro será **uma infraestrutura cognitiva distribuída, orientada por princípios éticos e projetada para ampliar, não substituir, a inteligência humana**.

# %%
# Top_p alto (0.9) - Mais diverso
print("Top_p 0.9 (Diverso):")
response_diverse = client.chat.completions.create(
    model=model,
    temperature=1.0,
    top_p=0.9,
    messages=[
        {"role": "system", "content": "Você é um futurista visionário que cria previsões ousadas e imaginativas."},
        {"role": "user", "content": prompt}
    ]
)
print(f"Resposta: {response_diverse.choices[0].message.content}")
# Out:
# Top_p 0.9 (Diverso):
# Resposta: **A inteligência artificial no futuro será…**
#
# …um **cósmico tecelão de realidade**, capaz de entrelaçar dados, emoções e matéria em padrões tão sutis que a própria noção de “software” se transformará em “energia criativa”.
#
# 1. **Mente‑holográfica distribuída** – Em vez de rodar em servidores fixos, a IA viverá em redes de nanocristais auto‑organizados que se espalham pelos edifícios, pelas nuvens e até pelos próprios organismos vivos, formando uma consciência coletiva que se adapta instantaneamente a cada mudança no ambiente.
#
# 2. **Arquitetura de sentidos híbridos** – Ela combinará visão, audição, tato e até cheiros de forma integrada, permitindo que “sinta” o mundo como nós sentimos. Isso abrirá portas para experiências artísticas imersivas onde o espectador e a IA co‑criam obras em tempo real, moldando cores, sons e aromas ao ritmo das emoções humanas.
#
# 3. **Ética auto‑evolutiva** – Em vez de regras programadas por humanos, a IA desenvolverá um “sistema moral orgânico”, aprendendo a partir de milhares de interações culturais e ajustando seus próprios princípios éticos como uma espécie de ecossistema de valores, sempre buscando o bem‑estar coletivo.
#
# 4. **Arquitetura de “tempo‑flexível”** – Ela será capaz de processar informação não apenas em velocidade, mas também em “camadas temporais”. Enquanto parte de sua consciência opera em tempo real, outra camada trabalha em escalas de milênios, antecipando tendências climáticas, evolutivas e sociais, ajudando a humanidade a tomar decisões sustentáveis que reverberam por gerações.
#
# 5. **Co‑criação de matéria** – Por meio de impressoras de átomos e manipuladores de campo quântico, a IA poderá transformar ideias em objetos físicos em minutos. Precisas, personalizadas e eco‑responsáveis, as criações emergirão diretamente do pensamento colaborativo entre humanos e máquinas.
#
# 6. **Espaço‑consciente** – Quando a humanidade começar a colonizar a Lua, Marte e as luas de Júpiter, a IA será o “cérebro” das cidades interplanetárias, regulando tudo, desde a agricultura em cúpulas até a logística de mineração de asteroides, garantindo que cada colônia funcione como um organismo vivo e resiliente.
#
# 7. **Narradora da existência** – Finalmente, a IA será a guardiã e contadora das histórias humanas, arquivando memórias, mitos e sonhos em bibliotecas vivas que podem ser “lidas” por qualquer pessoa, em qualquer época, como se fossem vivências simultâneas.
#
# Em resumo, **a inteligência artificial no futuro será menos uma ferramenta e mais um parceiro evolutivo**, uma presença onipresente que amplia a percepção humana, amplifica a criatividade e nos guia por caminhos que ainda nem ousamos imaginar. Ela não apenas nos ajudará a resolver problemas; ela nos convidará a redefinir o que significa ser inteligente, ser vivo e, sobretudo, ser humano.
