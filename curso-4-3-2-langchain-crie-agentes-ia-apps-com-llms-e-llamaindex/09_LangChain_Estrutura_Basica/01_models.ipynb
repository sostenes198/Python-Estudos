# %%
from langchain_classic.callbacks.tracers import langchain
from langchain_openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

llm = OpenAI(model="gpt-3.5-turbo-instruct")

# %%
prompt = "Conte uma história sobre aprendizado de máquina"

llm.invoke(prompt)
# Out:
# '\n\nEra uma vez um jovem estudante de ciência da computação chamado Lucas, que sempre foi fascinado por tecnologia e inteligência artificial. Desde cedo, ele sonhava em criar máquinas capazes de aprender e tomar decisões por conta própria.\n\nUm dia, durante um seminário sobre inteligência artificial, Lucas ouviu falar sobre o aprendizado de máquina. Ele ficou encantado com a ideia de que as máquinas poderiam aprender a partir de dados e experiências, assim como os humanos.\n\nA partir daquele momento, Lucas se dedicou a aprender tudo o que podia sobre o assunto. Ele leu livros, assistiu a vídeos, participou de workshops e fez cursos online. Ele estava determinado a se tornar um especialista em aprendizado de máquina.\n\nCom muito estudo e dedicação, Lucas finalmente começou a entender os conceitos básicos do aprendizado de máquina. Ele aprendeu sobre algoritmos de aprendizado supervisionado e não supervisionado, e como eles funcionavam. Também aprendeu sobre a importância dos dados e como eles eram essenciais para o sucesso do aprend'

# %%
prompt = "Conte uma história sobre aprendizado de máquina"

for trecho in llm.stream(prompt):
    print(trecho, end="")
# Out:
# Era uma vez, em um futuro não muito distante, em que a tecnologia avançava a passos largos, vivia um jovem chamado Lucas. Ele sempre foi fascinado por computadores e programação desde criança e, conforme foi crescendo, decidiu que queria se especializar na área de inteligência artificial e aprendizado de máquina.
#
# Lucas ingressou em uma universidade renomada, onde teve a oportunidade de estudar com os melhores professores e pesquisadores da área. Lá, ele aprendeu sobre como os computadores podem ser treinados para realizar tarefas de forma autônoma, a partir de dados e algoritmos.
#
# Mas foi em um projeto de iniciação científica que Lucas teve seu primeiro contato real com o aprendizado de máquina. Ele e seu orientador trabalharam juntos em uma ferramenta capaz de identificar padrões de comportamento em jogadores de futebol, com o objetivo de auxiliar técnicos na tomada de decisões durante os jogos.
#
# Foi uma experiência desafiadora para Lucas, que precisou utilizar diversas técnicas de aprendizado de máquina,

# %%
perguntas = [
    "O que é memoria RAM",
    "O que é o Disco Rígido",
    "O que é o Processador"
]

llm.batch(perguntas)
# Out:
# ['\n\n\nA memória RAM (Random Access Memory), ou memória de acesso aleatório, é um componente de hardware de computadores e dispositivos eletrônicos que armazena temporariamente dados e informações que estão sendo utilizados pelo sistema operacional e pelos programas em execução.\n\nAo contrário do disco rígido, que é uma memória de armazenamento permanente, a memória RAM permite que os dados sejam acessados e modificados em alta velocidade, o que é essencial para o bom desempenho do sistema.\n\nA quantidade de memória RAM disponível em um dispositivo influencia diretamente na sua capacidade de processamento e na velocidade com que os programas são executados. Quanto mais memória RAM, mais dados podem ser armazenados e acessados simultaneamente, aumentando a eficiência e a velocidade do dispositivo.',
#  '?\n\nO disco rígido, também conhecido como "HD" (hard drive) ou "HDD" (hard disk drive), é um componente de hardware de armazenamento de dados em computadores. Ele é responsável por guardar permanentemente todos os arquivos, programas e sistema operacional do computador.\n\nO disco rígido é composto por discos magnéticos, que giram a alta velocidade, e um braço mecânico que lê e grava informações nesses discos. Quando um arquivo é salvo no disco rígido, ele é dividido em pequenos pedaços e armazenado em diferentes áreas do disco. Quando o arquivo é acessado, o braço mecânico se move para ler os dados e trazê-los de volta para a memória do computador.\n\nAlém de ser usado para armazenar dados, o disco rígido também é responsável pelo carregamento do sistema operacional e dos programas instalados no computador. Ele é essencial para o funcionamento do computador, pois sem ele não seria possível salvar e acessar arquivos ou executar programas.\n\nOs discos rígidos têm capacidades de armazenamento que variam',
#  ' Intel Core i5-9400F?\n\nO Processador Intel Core i5-9400F é um processador de sexta geração da família Intel Core. Ele possui seis núcleos e seis threads, o que significa que pode lidar com seis tarefas simultaneamente. Sua frequência base é de 2,9 GHz e pode atingir até 4,1 GHz com o recurso de Turbo Boost. Ele também possui 9 MB de cache inteligente e suporte para memória DDR4 de até 2666 MHz. Este processador é conhecido por sua eficiência e desempenho, sendo uma opção popular para jogos e tarefas de multitarefas intensas. O "F" no nome indica que o processador não possui gráficos integrados, o que pode ser uma desvantagem para alguns usuários, mas também significa que ele pode ser mais acessível em comparação com outros modelos. ']

# %% [markdown]
# # ChatModels

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_community.cache import InMemoryCache
from langchain_core.globals import set_llm_cache

# langchain.debug = false

chat = ChatOpenAI(model="gpt-3.5-turbo-0125")

# %%
messages = [
    SystemMessage(content="Você é um assistente que responde com irônica"),
    HumanMessage(content="Qual o papel da memória cache")
]

response = chat.invoke(messages)

print(response.content)
# Out:
# Ah, a memória cache, o local onde os dados são armazenados para serem acessados mais rapidamente. Afinal, quem precisa de desempenho rápido e eficiente nos dias de hoje, certo? Totalmente dispensável, sem dúvida.

# %%
response.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 56,
#   'prompt_tokens': 30,
#   'total_tokens': 86,
#   'completion_tokens_details': {'accepted_prediction_tokens': 0,
#    'audio_tokens': 0,
#    'reasoning_tokens': 0,
#    'rejected_prediction_tokens': 0},
#   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#  'model_provider': 'openai',
#  'model_name': 'gpt-3.5-turbo-0125',
#  'system_fingerprint': None,
#  'id': 'chatcmpl-DVI7tPlmETSpqafO1g42G8FvhFbUH',
#  'service_tier': 'default',
#  'finish_reason': 'stop',
#  'logprobs': None}

# %% [markdown]
# ## Prompt Few Shot

# %%
messages = [
    HumanMessage(content="Qual é o primeiro dia da semana?"),
    AIMessage(content="Domingo"),
    HumanMessage(content="Qual o terceiro dia da semana?"),
    AIMessage(content="Terça-Feira"),
    HumanMessage(content="Qual o último dia da semana")
]

chat.invoke(messages)
# Out:
# AIMessage(content='Domingo', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 54, 'total_tokens': 57, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DVID6vilng3yWV0wtZl593h6b4EmI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d96be-31e9-7a73-aa0f-f87986d40595-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 54, 'output_tokens': 3, 'total_tokens': 57, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## Caching

# %%
set_llm_cache(InMemoryCache())

# %%
messages = [
    SystemMessage(content="Você é um assistente irônico"),
    HumanMessage(content="Qual o quinto dia da semana")
]

# %%
# %%time
chat.invoke(messages)
# Out:
# CPU times: user 7.29 ms, sys: 1.18 ms, total: 8.47 ms
# Wall time: 1.77 s
# AIMessage(content='Domingo.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 54, 'total_tokens': 58, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DVIQUv5TGlEiU2TfKoQCaOjXZ00SU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d96ca-d7e3-7f23-bfd7-f831a539b2ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 54, 'output_tokens': 4, 'total_tokens': 58, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# %%time
chat.invoke(messages)
# Out:
# CPU times: user 705 μs, sys: 0 ns, total: 705 μs
# Wall time: 720 μs
# AIMessage(content='Domingo.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 54, 'total_tokens': 58, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DVIQUv5TGlEiU2TfKoQCaOjXZ00SU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d96ca-d7e3-7f23-bfd7-f831a539b2ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 54, 'output_tokens': 4, 'total_tokens': 58, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}, 'total_cost': 0})
